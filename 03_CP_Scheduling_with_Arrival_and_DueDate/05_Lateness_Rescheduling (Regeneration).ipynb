# %% [markdown]
# # Rescheduling mit Tardiness (Summe)
# > Planunghorizont Tag 0: 2 Tage
# > Rescheduling des Tages 1

# %%
max_time = 60*30 # 1/2h

# %%
import time

# %%
from ortools.sat.python import cp_model
import pandas as pd
import numpy as np
import math

pd.set_option('display.max_rows', 20)

# %%
import utils.presenter as show
import utils.checker as check

import utils.schedule_interarrival as sit
import utils.scheduling_solver as ssv
import utils.rescheduling_solver_tardiness as rssv

from ProductionDaySimulation import ProductionDaySimulation

# %%
import utils.rolling_planning.init_jobs_times as rp_init
import utils.schedule_deadline as deadline_gen

# %%
df_instance = pd.read_csv("data/00_instance.csv")
df_instance
# Out:
#       Job  Operation Machine  Processing Time
# 0   job 0          0      M0               29
# 1   job 0          1      M1               78
# 2   job 0          2      M2                9
# 3   job 0          3      M3               36
# 4   job 0          4      M4               49
# ..    ...        ...     ...              ...
# 95  job 9          5      M9               76
# 96  job 9          6      M5               47
# 97  job 9          7      M3               52
# 98  job 9          8      M4               90
# 99  job 9          9      M7               45
#
# [100 rows x 4 columns]

# %%
df_jssp, df_arrivals = rp_init.init_jobs_with_arrivals(df_instance, 3,  u_b_mmax = 0.95)
df_jssp
# Out:
#          Job Operation Machine Processing Time
# 0    Job_000         0      M0              29
# 1    Job_000         1      M1              78
# 2    Job_000         2      M2               9
# 3    Job_000         3      M3              36
# 4    Job_000         4      M4              49
# ..       ...       ...     ...             ...
# 565  Job_056         5      M9              76
# 566  Job_056         6      M5              47
# 567  Job_056         7      M3              52
# 568  Job_056         8      M4              90
# 569  Job_056         9      M7              45
#
# [570 rows x 4 columns]

# %%
# Arrival-Werte durchmischen (aber nicht verändern)
#df_arrivals['Arrival'] = df_arrivals['Arrival'].sample(frac=1.0, random_state=42).reset_index(drop=True)
#df_arrivals

# %%
df_times = deadline_gen.get_times_df(df_jssp, df_arrivals, ssv.schedule_fcfs_with_arrivals, target_service=1.0)
df_times["Arrival"] = np.floor(df_times["Arrival"]).astype(int)
df_times["Deadline"] = np.ceil(df_times["Deadline"]).astype(int)
df_times
# Out:
#         Job  Arrival  Deadline
# 0   Job_000        0      1151
# 1   Job_001       83      1570
# 2   Job_002      144      1800
# 3   Job_003      197      2106
# 4   Job_004      233      1379
# ..      ...      ...       ...
# 52  Job_052     4008      5917
# 53  Job_053     4014      5160
# 54  Job_054     4015      5671
# 55  Job_055     4134      5286
# 56  Job_056     4234      5808
#
# [57 rows x 3 columns]

# %% [markdown]
# ## I) Complete Scheduling

# %%
starting_time = time.time()

# Scheduling
df_plan = ssv.solve_cp_jssp_lateness_by_tardiness_and_earliness(df_jssp, df_times,w_t = 5,
                                                                msg=False, timeLimit=max_time, gapRel= 0.00)
df_plan

# Informationen
ending_time = time.time()
solver_duration = ending_time - starting_time
print(f"\nScheduling-Dauer: {int(solver_duration // 60)} Minuten und {(solver_duration % 60):.2f} Sekunden.")
df_plan
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 126.00
# Best Objective Bound  : 126.00
# Laufzeit              : 10.67 Sekunden
#
# Scheduling-Dauer: 0 Minuten und 11.00 Sekunden.
#          Job  Operation  Arrival  Deadline Machine  Start  Processing Time  \
# 0    Job_000          0        0      1151      M0      0               29
# 1    Job_000          1        0      1151      M1     29               78
# 2    Job_001          0       83      1570      M0     83               43
# 3    Job_000          2        0      1151      M2    107                9
# 4    Job_000          3        0      1151      M3    116               36
# ..       ...        ...      ...       ...     ...    ...              ...
# 565  Job_051          9     4003      5449      M7   5424               25
# 566  Job_049          9     3774      5515      M8   5441               74
# 567  Job_054          9     4015      5671      M4   5638               33
# 568  Job_056          9     4234      5808      M7   5763               45
# 569  Job_052          9     4008      5917      M5   5874               43
#
#       End  Lateness  Tardiness  Earliness
# 0      29     -1122          0       1122
# 1     107     -1044          0       1044
# 2     126     -1444          0       1444
# 3     116     -1035          0       1035
# 4     152      -999          0        999
# ..    ...       ...        ...        ...
# 565  5449         0          0          0
# 566  5515         0          0          0
# 567  5671         0          0          0
# 568  5808         0          0          0
# 569  5917         0          0          0
#
# [570 rows x 11 columns]

# %%
show.plot_gantt_machines(df_plan)

check.is_machine_conflict_free(df_plan)
check.is_operation_sequence_correct(df_plan)
check.is_job_timing_correct(df_plan)
check.is_start_correct(df_plan)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Für alle Jobs ist die Operationssequenz korrekt.
# + Zeitliche technologische Reihenfolge korrekt.
# + Alle Operation starten erst nach Arrival des Job
# True

# %% [markdown]
# ## II) Erster Tag (Tag 0)

# %% [markdown]
# ### a) Simulation

# %%
day_length = 1440

# %%
day_numb = 0

day_start = day_length*day_numb 
day_end = day_start + day_length

# %%
simulation = ProductionDaySimulation(df_plan, vc=0.35)
df_execution, df_undone = simulation.run(start_time = day_start, end_time=day_end)
# Out:
# [00:00:00] Job_000 started on M0
# [00:13:11] Job_000 finished on M0 (after 13 minutes 12 seconds)
# [00:29:00] Job_000 started on M1
# [01:23:00] Job_001 started on M0
# [01:58:19] Job_001 finished on M0 (after 35 minutes 20 seconds)
# [02:06:00] Job_001 started on M2
# [02:16:13] Job_000 finished on M1 (after 107 minutes 13 seconds)
# [02:24:00] Job_002 started on M1
# [04:01:14] Job_002 finished on M1 (after 97 minutes 14 seconds)
# [04:01:14] Job_003 started on M1
# [04:01:14] Job_002 started on M0
# [04:19:52] Job_001 finished on M2 (after 133 minutes 52 seconds)
# [04:19:52] Job_000 started on M2
# [04:19:52] Job_001 started on M4
# [04:27:41] Job_000 finished on M2 (after 07 minutes 49 seconds)
# [04:27:41] Job_004 started on M2
# [04:27:41] Job_000 started on M3
# [04:46:51] Job_004 finished on M2 (after 19 minutes 10 seconds)
# [04:55:25] Job_000 finished on M3 (after 27 minutes 44 seconds)
# [05:02:00] Job_005 started on M2
# [05:21:54] Job_001 finished on M4 (after 62 minutes 02 seconds)
# [05:21:54] Job_000 started on M4
# [05:21:54] Job_001 started on M9
# [05:28:15] Job_003 finished on M1 (after 87 minutes 01 second)
# [05:33:15] Job_001 finished on M9 (after 11 minutes 20 seconds)
# [05:33:15] Job_001 started on M3
# [05:48:00] Job_006 started on M1
# [05:51:41] Job_002 finished on M0 (after 110 minutes 27 seconds)
# [05:51:41] Job_004 started on M0
# [06:03:47] Job_004 finished on M0 (after 12 minutes 06 seconds)
# [06:21:50] Job_006 finished on M1 (after 33 minutes 50 seconds)
# [06:21:50] Job_004 started on M1
# [06:30:48] Job_005 finished on M2 (after 88 minutes 48 seconds)
# [06:30:48] Job_003 started on M2
# [06:34:00] Job_006 started on M0
# [06:43:34] Job_004 finished on M1 (after 21 minutes 44 seconds)
# [06:43:34] Job_004 started on M5
# [06:58:35] Job_000 finished on M4 (after 96 minutes 41 seconds)
# [07:02:00] Job_005 started on M1
# [07:03:08] Job_005 finished on M1 (after 01 minute 08 seconds)
# [07:06:36] Job_006 finished on M0 (after 32 minutes 36 seconds)
# [07:37:33] Job_004 finished on M5 (after 53 minutes 59 seconds)
# [07:37:33] Job_000 started on M5
# [07:41:06] Job_001 finished on M3 (after 127 minutes 51 seconds)
# [07:41:06] Job_002 started on M3
# [07:41:06] Job_001 started on M1
# [07:48:23] Job_003 finished on M2 (after 77 minutes 36 seconds)
# [07:50:57] Job_000 finished on M5 (after 13 minutes 23 seconds)
# [07:50:57] Job_005 started on M5
# [07:50:57] Job_000 started on M6
# [08:01:00] Job_003 started on M0
# [08:17:34] Job_002 finished on M3 (after 36 minutes 29 seconds)
# [08:17:34] Job_006 started on M3
# [08:17:34] Job_002 started on M2
# [08:27:47] Job_005 finished on M5 (after 36 minutes 50 seconds)
# [08:35:12] Job_001 finished on M1 (after 54 minutes 07 seconds)
# [08:58:01] Job_000 finished on M6 (after 67 minutes 04 seconds)
# [08:58:01] Job_001 started on M6
# [08:58:01] Job_000 started on M7
# [09:28:16] Job_002 finished on M2 (after 70 minutes 41 seconds)
# [09:28:16] Job_007 started on M2
# [09:28:16] Job_002 started on M8
# [09:29:52] Job_001 finished on M6 (after 31 minutes 51 seconds)
# [09:29:52] Job_001 started on M5
# [09:30:04] Job_003 finished on M0 (after 89 minutes 04 seconds)
# [09:30:04] Job_003 started on M4
# [09:37:44] Job_006 finished on M3 (after 80 minutes 10 seconds)
# [09:37:44] Job_004 started on M3
# [09:49:07] Job_007 finished on M2 (after 20 minutes 51 seconds)
# [09:49:07] Job_006 started on M2
# [09:51:46] Job_000 finished on M7 (after 53 minutes 46 seconds)
# [09:59:00] Job_007 started on M0
# [10:04:02] Job_006 finished on M2 (after 14 minutes 56 seconds)
# [10:04:02] Job_006 started on M6
# [10:21:30] Job_004 finished on M3 (after 43 minutes 46 seconds)
# [10:21:30] Job_005 started on M3
# [10:24:50] Job_006 finished on M6 (after 20 minutes 47 seconds)
# [10:25:51] Job_001 finished on M5 (after 55 minutes 59 seconds)
# [10:25:51] Job_006 started on M5
# [10:25:51] Job_001 started on M7
# [10:39:00] Job_007 finished on M0 (after 40 minutes)
# [10:49:20] Job_006 finished on M5 (after 23 minutes 29 seconds)
# [10:49:20] Job_006 started on M9
# [10:52:30] Job_003 finished on M4 (after 82 minutes 26 seconds)
# [10:52:30] Job_004 started on M4
# [10:52:30] Job_003 started on M6
# [10:53:58] Job_002 finished on M8 (after 85 minutes 42 seconds)
# [10:53:58] Job_000 started on M8
# [10:53:58] Job_002 started on M5
# [11:03:31] Job_003 finished on M6 (after 11 minutes 01 second)
# [11:10:28] Job_002 finished on M5 (after 16 minutes 31 seconds)
# [11:25:00] Job_007 started on M1
# [11:32:42] Job_006 finished on M9 (after 43 minutes 22 seconds)
# [11:48:00] Job_008 started on M0
# [11:48:01] Job_000 finished on M8 (after 54 minutes 04 seconds)
# [11:48:01] Job_006 started on M8
# [11:54:48] Job_001 finished on M7 (after 88 minutes 57 seconds)
# [11:54:48] Job_002 started on M7
# [12:02:26] Job_002 finished on M7 (after 07 minutes 38 seconds)
# [12:02:26] Job_002 started on M6
# [12:03:23] Job_005 finished on M3 (after 101 minutes 53 seconds)
# [12:12:22] Job_004 finished on M4 (after 79 minutes 52 seconds)
# [12:12:26] Job_007 finished on M1 (after 47 minutes 26 seconds)
# [12:12:26] Job_007 started on M5
# [12:20:00] Job_009 started on M1
# [12:58:43] Job_008 finished on M0 (after 70 minutes 44 seconds)
# [13:08:22] Job_007 finished on M5 (after 55 minutes 56 seconds)
# [13:25:00] Job_007 started on M4
# [13:35:28] Job_006 finished on M8 (after 107 minutes 27 seconds)
# [13:35:28] Job_005 started on M8
# [13:35:28] Job_006 started on M7
# [13:41:47] Job_007 finished on M4 (after 16 minutes 48 seconds)
# [14:05:00] Job_010 started on M2
# [14:24:17] Job_006 finished on M7 (after 48 minutes 49 seconds)
# [14:32:49] Job_005 finished on M8 (after 57 minutes 20 seconds)
# [14:32:49] Job_004 started on M8
# [14:32:49] Job_005 started on M9
# [14:53:57] Job_010 finished on M2 (after 48 minutes 57 seconds)
# [14:53:57] Job_010 started on M0
# [14:57:13] Job_004 finished on M8 (after 24 minutes 25 seconds)
# [14:57:13] Job_003 started on M8
# [14:57:13] Job_004 started on M7
# [15:11:59] Job_009 finished on M1 (after 171 minutes 59 seconds)
# [15:11:59] Job_008 started on M1
# [15:26:52] Job_002 finished on M6 (after 204 minutes 26 seconds)
# [15:26:52] Job_007 started on M6
# [15:35:01] Job_004 finished on M7 (after 37 minutes 48 seconds)
# [15:47:27] Job_010 finished on M0 (after 53 minutes 31 seconds)
# [15:47:27] Job_009 started on M0
# [16:02:23] Job_009 finished on M0 (after 14 minutes 56 seconds)
# [16:02:23] Job_012 started on M0
# [16:02:23] Job_009 started on M2
# [16:03:38] Job_003 finished on M8 (after 66 minutes 25 seconds)
# [16:03:38] Job_003 started on M7
# [16:07:19] Job_005 finished on M9 (after 94 minutes 31 seconds)
# [16:07:19] Job_002 started on M9
# [16:32:02] Job_012 finished on M0 (after 29 minutes 40 seconds)
# [16:32:02] Job_005 started on M0
# [16:44:33] Job_002 finished on M9 (after 37 minutes 14 seconds)
# [16:44:33] Job_004 started on M9
# [17:10:07] Job_005 finished on M0 (after 38 minutes 05 seconds)
# [17:10:07] Job_011 started on M0
# [17:20:04] Job_008 finished on M1 (after 128 minutes 05 seconds)
# [17:20:04] Job_010 started on M1
# [17:20:04] Job_008 started on M3
# [17:37:25] Job_003 finished on M7 (after 93 minutes 47 seconds)
# [17:43:25] Job_009 finished on M2 (after 101 minutes 02 seconds)
# [17:43:25] Job_012 started on M2
# [17:53:48] Job_010 finished on M1 (after 33 minutes 44 seconds)
# [17:53:48] Job_010 started on M5
# [18:02:25] Job_004 finished on M9 (after 77 minutes 52 seconds)
# [18:40:33] Job_007 finished on M6 (after 193 minutes 41 seconds)
# [18:40:33] Job_005 started on M6
# [18:40:33] Job_007 started on M8
# [18:50:00] Job_000 started on M9
# [18:52:01] Job_007 finished on M8 (after 11 minutes 28 seconds)
# [18:57:14] Job_010 finished on M5 (after 63 minutes 26 seconds)
# [18:58:15] Job_012 finished on M2 (after 74 minutes 49 seconds)
# [18:58:15] Job_012 started on M4
# [18:59:46] Job_008 finished on M3 (after 99 minutes 42 seconds)
# [18:59:46] Job_003 started on M3
# [18:59:46] Job_008 started on M5
# [19:02:28] Job_011 finished on M0 (after 112 minutes 20 seconds)
# [19:02:28] Job_011 started on M1
# [19:06:09] Job_000 finished on M9 (after 16 minutes 09 seconds)
# [19:06:09] Job_007 started on M9
# [19:27:34] Job_007 finished on M9 (after 21 minutes 25 seconds)
# [19:27:34] Job_007 started on M7
# [19:29:38] Job_008 finished on M5 (after 29 minutes 52 seconds)
# [19:29:38] Job_008 started on M2
# [19:42:45] Job_005 finished on M6 (after 62 minutes 12 seconds)
# [19:42:45] Job_009 started on M6
# [19:47:57] Job_009 finished on M6 (after 05 minutes 12 seconds)
# [19:47:57] Job_009 started on M8
# [20:03:31] Job_007 finished on M7 (after 35 minutes 57 seconds)
# [20:10:17] Job_011 finished on M1 (after 67 minutes 50 seconds)
# [20:10:17] Job_016 started on M1
# [20:27:58] Job_003 finished on M3 (after 88 minutes 12 seconds)
# [20:27:58] Job_011 started on M3
# [20:27:58] Job_003 started on M9
# [20:31:35] Job_008 finished on M2 (after 61 minutes 56 seconds)
# [20:31:35] Job_015 started on M2
# [20:38:13] Job_012 finished on M4 (after 99 minutes 59 seconds)
# [20:38:13] Job_010 started on M4
# [20:40:45] Job_003 finished on M9 (after 12 minutes 46 seconds)
# [20:40:45] Job_008 started on M9
# [20:48:53] Job_015 finished on M2 (after 17 minutes 19 seconds)
# [20:48:53] Job_013 started on M2
# [20:48:53] Job_015 started on M0
# [20:53:46] Job_015 finished on M0 (after 04 minutes 52 seconds)
# [21:00:55] Job_008 finished on M9 (after 20 minutes 10 seconds)
# [21:00:55] Job_012 started on M9
# [21:06:06] Job_009 finished on M8 (after 78 minutes 09 seconds)
# [21:10:03] Job_012 finished on M9 (after 09 minutes 08 seconds)
# [21:10:03] Job_009 started on M9
# [21:17:11] Job_010 finished on M4 (after 38 minutes 58 seconds)
# [21:17:11] Job_005 started on M4
# [21:17:11] Job_010 started on M6
# [21:21:52] Job_005 finished on M4 (after 04 minutes 41 seconds)
# [21:25:52] Job_011 finished on M3 (after 57 minutes 53 seconds)
# [21:25:52] Job_012 started on M3
# [21:25:52] Job_011 started on M5
# [21:43:55] Job_016 finished on M1 (after 93 minutes 37 seconds)
# [21:43:55] Job_015 started on M1
# [21:43:55] Job_016 started on M0
# [21:54:12] Job_011 finished on M5 (after 28 minutes 20 seconds)
# [21:56:01] Job_015 finished on M1 (after 12 minutes 06 seconds)
# [21:56:01] Job_014 started on M1
# [21:56:01] Job_015 started on M5
# [22:13:57] Job_010 finished on M6 (after 56 minutes 46 seconds)
# [22:13:57] Job_004 started on M6
# [22:13:57] Job_010 started on M8
# [22:24:36] Job_013 finished on M2 (after 95 minutes 43 seconds)
# [22:24:36] Job_011 started on M2
# [22:25:52] Job_009 finished on M9 (after 75 minutes 49 seconds)
# [22:45:02] Job_010 finished on M8 (after 31 minutes 05 seconds)
# [22:45:02] Job_010 started on M9
# [22:50:08] Job_004 finished on M6 (after 36 minutes 11 seconds)
# [22:59:00] Job_008 started on M6
# [22:59:29] Job_015 finished on M5 (after 63 minutes 28 seconds)
# [22:59:29] Job_009 started on M5
# [23:07:31] Job_016 finished on M0 (after 83 minutes 36 seconds)
# [23:07:31] Job_017 started on M0
# [23:16:44] Job_012 finished on M3 (after 110 minutes 52 seconds)
# [23:16:44] Job_015 started on M3
# [23:32:01] Job_017 finished on M0 (after 24 minutes 31 seconds)
# [23:39:10] Job_010 finished on M9 (after 54 minutes 08 seconds)
# [23:39:10] Job_010 started on M7
# [23:39:29] Job_009 finished on M5 (after 40 minutes 01 second)
# [23:44:42] Job_015 finished on M3 (after 27 minutes 58 seconds)
# [23:44:42] Job_016 started on M3
# [23:44:42] Job_015 started on M4
# [23:47:21] Job_008 finished on M6 (after 48 minutes 22 seconds)
# [23:47:45] Job_014 finished on M1 (after 111 minutes 44 seconds)
# [23:47:45] Job_013 started on M1
# [23:51:01] Job_013 finished on M1 (after 03 minutes 16 seconds)
# [23:51:01] Job_012 started on M1
# [23:51:01] Job_013 started on M5
# [24:00:00] Job_019 started on M0
# [24:02:46] Job_011 finished on M2 (after 98 minutes 10 seconds)
# [24:02:46] Job_014 interrupted before machine M2 — would start too late (after 24:00:00)
# [24:02:46] Job_011 interrupted before machine M9 — would start too late (after 24:00:00)
# [24:05:23] Job_010 finished on M7 (after 26 minutes 13 seconds)
# [24:05:23] Job_008 interrupted before machine M7 — would start too late (after 24:00:00)
# [24:19:53] Job_016 finished on M3 (after 35 minutes 11 seconds)
# [24:19:53] Job_009 interrupted before machine M3 — would start too late (after 24:00:00)
# [24:20:41] Job_019 finished on M0 (after 20 minutes 41 seconds)
# [24:26:23] Job_012 finished on M1 (after 35 minutes 23 seconds)
# [24:26:23] Job_017 interrupted before machine M1 — would start too late (after 24:00:00)
# [24:26:23] Job_012 interrupted before machine M6 — would start too late (after 24:00:00)
# [24:27:00] Job_016 interrupted before machine M2 — would start too late (after 24:00:00)
# [24:44:26] Job_013 finished on M5 (after 53 minutes 25 seconds)
# [24:44:26] Job_013 interrupted before machine M3 — would start too late (after 24:00:00)
# [25:28:43] Job_015 finished on M4 (after 104 minutes 01 second)
#
# [25:28:43] Simulation ended! There are no more active Operations

# %%
df_undone
# Out:
#          Job  Operation  Arrival Machine  Planned Start  Processing Time
# 0    Job_011          5      894      M9           1363               11
# 1    Job_014          1     1128      M2           1363               95
# 2    Job_017          1     1254      M1           1374               78
# 3    Job_009          7      740      M3           1391               52
# 4    Job_008          7      708      M7           1419               89
# ..       ...        ...      ...     ...            ...              ...
# 442  Job_051          9     4003      M7           5424               25
# 443  Job_049          9     3774      M8           5441               74
# 444  Job_054          9     4015      M4           5638               33
# 445  Job_056          9     4234      M7           5763               45
# 446  Job_052          9     4008      M5           5874               43
#
# [447 rows x 6 columns]

# %%
if not df_execution.empty:
    show.plot_gantt_machines(df_execution, title=f"Gantt-Diagramm ab Tag {day_numb}", duration_column="Simulated Processing Time")
else:
    print(f"Nothing executed on day {day_numb}")

# %% [markdown]
# ### b) Verbleibene Jobs (Rest)

# %%
df_rest = df_plan.merge(df_execution[["Job", "Machine"]], on=["Job", "Machine"], how="left", indicator=True)
df_rest = df_rest[df_rest["_merge"] == "left_only"].drop(columns=["_merge"])
df_rest = df_rest.sort_values(by=["Arrival", "Start"]).reset_index(drop=True)
df_rest
# Out:
#          Job  Operation  Arrival  Deadline Machine  Start  Processing Time  \
# 0    Job_001          9       83      1570      M8   1540               30
# 1    Job_002          9      144      1800      M4   1767               33
# 2    Job_003          9      197      2106      M5   2063               43
# 3    Job_005          9      302      1748      M7   1723               25
# 4    Job_006          9      340      1553      M4   1498               55
# ..       ...        ...      ...       ...     ...    ...              ...
# 442  Job_056          5     4234      5808      M9   4667               76
# 443  Job_056          6     4234      5808      M5   4743               47
# 444  Job_056          7     4234      5808      M3   4790               52
# 445  Job_056          8     4234      5808      M4   4842               90
# 446  Job_056          9     4234      5808      M7   5763               45
#
#       End  Lateness  Tardiness  Earliness
# 0    1570         0          0          0
# 1    1800         0          0          0
# 2    2106         0          0          0
# 3    1748         0          0          0
# 4    1553         0          0          0
# ..    ...       ...        ...        ...
# 442  4743     -1065          0       1065
# 443  4790     -1018          0       1018
# 444  4842      -966          0        966
# 445  4932      -876          0        876
# 446  5808         0          0          0
#
# [447 rows x 11 columns]

# %%
allowed = df_rest["Job"].unique() 
df_time_rest = df_times[df_times["Job"].isin(allowed)].copy()
df_time_rest
# Out:
#         Job  Arrival  Deadline
# 1   Job_001       83      1570
# 2   Job_002      144      1800
# 3   Job_003      197      2106
# 5   Job_005      302      1748
# 6   Job_006      340      1553
# ..      ...      ...       ...
# 52  Job_052     4008      5917
# 53  Job_053     4014      5160
# 54  Job_054     4015      5671
# 55  Job_055     4134      5286
# 56  Job_056     4234      5808
#
# [55 rows x 3 columns]

# %% [markdown]
# ## III) Rescheduling
# > vereinfacht, ohne neu Aufträge (nur der Rest)

# %%
# Reduktion der bereits ausgeführten Operationen auf die relevanten für die nächsten Tage
df_execution_important = df_execution[df_execution["End"] >= 1440]
df_execution_important
# Out:
#          Job  Operation  Arrival Machine    Start  Simulated Processing Time  \
# 96   Job_010          8      845      M7  1419.17                      26.22
# 101  Job_011          4      894      M2  1344.61                      98.17
# 107  Job_012          5      950      M1  1431.02                      35.38
# 110  Job_013          2     1123      M5  1431.02                      53.42
# 117  Job_015          5     1134      M4  1424.71                     104.02
# 120  Job_016          2     1135      M3  1424.71                      35.18
# 122  Job_019          0     1440      M0  1440.00                      20.69
#
#      Flow time      End
# 96      600.39  1445.39
# 101     548.78  1442.78
# 107     516.40  1466.40
# 110     361.44  1484.44
# 117     394.73  1528.73
# 120     324.89  1459.89
# 122      20.69  1460.69

# %%
from ortools.sat.python import cp_model
import pandas as pd
import math

def solve_cp_jssp_lateness_by_tardiness_and_earliness_with_fixed_ops(
    df_jssp: pd.DataFrame,
    df_arrivals_deadlines: pd.DataFrame,
    df_executed: pd.DataFrame,
    w_t: int = 5,
    w_e: int = 1,
    reschedule_start: float = 1440.0,
    sort_ascending: bool = False,
    msg: bool = False,
    timeLimit: int = 3600,
    gapRel: float = 0.0
) -> pd.DataFrame:
    model = cp_model.CpModel()

    # Sicherstellen, dass die Gewichte ganzzahlig sind (CP-SAT Voraussetzung)
    w_t = int(w_t)
    w_e = int(w_e)

    # === Vorbereitung: Jobliste, Ankünfte und Deadlines ===
    df_arrivals_deadlines = df_arrivals_deadlines.sort_values("Deadline", ascending=sort_ascending).reset_index(drop=True)
    arrival = df_arrivals_deadlines.set_index("Job")["Arrival"].to_dict()
    deadline = df_arrivals_deadlines.set_index("Job")["Deadline"].to_dict()
    jobs = df_arrivals_deadlines["Job"].tolist()

    # === Operationen je Job gruppieren ===
    ops_grouped = df_jssp.sort_values(["Job", "Operation"]).groupby("Job")
    all_ops, machines = [], set()
    for job in jobs:
        seq = []
        for _, row in ops_grouped.get_group(job).iterrows():
            op_id = int(row["Operation"])
            m = str(row["Machine"])
            d = int(round(row["Processing Time"]))
            seq.append((op_id, m, d))
            machines.add(m)
        all_ops.append(seq)

    # === Grober Planungshorizont (für obere Schranken) ===
    horizon = int(df_jssp["Processing Time"].sum() + max(deadline.values()))

    # === Fest eingeplante Operationen, die beim Rescheduling nicht verändert werden dürfen ===
    df_executed_fixed = df_executed[df_executed["End"] >= reschedule_start]
    fixed_ops = {
        m: list(grp[["Start", "End"]].itertuples(index=False, name=None))
        for m, grp in df_executed_fixed.groupby("Machine")
    }

    # === Variablen definieren ===
    starts, ends, intervals = {}, {}, {}
    weighted_terms = []

    for j, job in enumerate(jobs):
        for o, (op_id, m, d) in enumerate(all_ops[j]):
            suffix = f"{j}_{o}"
            start = model.NewIntVar(0, horizon, f"start_{suffix}")
            end = model.NewIntVar(0, horizon, f"end_{suffix}")
            interval = model.NewIntervalVar(start, d, end, f"interval_{suffix}")
            starts[(j, o)] = start
            ends[(j, o)] = end
            intervals[(j, o)] = (interval, m)

    # === Zielfunktion: gewichtete Tardiness + Earliness ===
    for j, job in enumerate(jobs):
        last_op_index = len(all_ops[j]) - 1
        job_end = ends[(j, last_op_index)]

        # Lateness = tatsächliches Ende – Deadline
        lateness = model.NewIntVar(-horizon, horizon, f"lateness_{j}")
        model.Add(lateness == job_end - deadline[job])

        # Tardiness = max(0, Lateness)
        tardiness = model.NewIntVar(0, horizon, f"tardiness_{j}")
        model.AddMaxEquality(tardiness, [lateness, 0])
        term_tardiness = model.NewIntVar(0, horizon * w_t, f"term_tardiness_{j}")
        model.Add(term_tardiness == w_t * tardiness)
        weighted_terms.append(term_tardiness)

        # Earliness = max(0, -Lateness)
        earliness = model.NewIntVar(0, horizon, f"earliness_{j}")
        model.AddMaxEquality(earliness, [-lateness, 0])
        term_earliness = model.NewIntVar(0, horizon * w_e, f"term_earliness_{j}")
        model.Add(term_earliness == w_e * earliness)
        weighted_terms.append(term_earliness)

        # Ankunftsbedingung + Rescheduling-Startzeit
        model.Add(starts[(j, 0)] >= arrival[job])
        model.Add(starts[(j, 0)] >= int(reschedule_start))

        # Falls vorherige Operationen des Jobs bereits geplant wurden
        if job in df_executed["Job"].values:
            last_fixed_end = df_executed[df_executed["Job"] == job]["End"].max()
            model.Add(starts[(j, 0)] >= int(math.ceil(last_fixed_end)))

        # Technologische Reihenfolge einhalten
        for o in range(1, len(all_ops[j])):
            model.Add(starts[(j, o)] >= ends[(j, o - 1)])

    # === Maschinenrestriktionen: Keine Überlappungen, auch mit fixen Intervallen ===
    for m in machines:
        machine_intervals = [interval for (j, o), (interval, mach) in intervals.items() if mach == m]

        for fixed_start, fixed_end in fixed_ops.get(m, []):
            start = math.floor(fixed_start)
            end = math.ceil(fixed_end)
            duration = end - start
            fixed_interval = model.NewIntervalVar(start, duration, end, f"fixed_{m}_{end}")
            machine_intervals.append(fixed_interval)

        model.AddNoOverlap(machine_intervals)

    # === Zielfunktion: Summe der gewichteten Tardiness- und Earliness-Werte minimieren ===
    model.Minimize(sum(weighted_terms))

    # === Solver-Konfiguration ===
    solver = cp_model.CpSolver()
    solver.parameters.log_search_progress = msg
    solver.parameters.relative_gap_limit = gapRel
    solver.parameters.max_time_in_seconds = timeLimit
    status = solver.Solve(model)

    # === Lösung extrahieren ===
    records = []
    if status in [cp_model.OPTIMAL, cp_model.FEASIBLE]:
        for j, job in enumerate(jobs):
            for o, (op_id, m, d) in enumerate(all_ops[j]):
                st = solver.Value(starts[(j, o)])
                ed = st + d
                lateness_val = ed - deadline[job]
                records.append({
                    "Job": job,
                    "Operation": op_id,
                    "Arrival": arrival[job],
                    "Deadline": deadline[job],
                    "Machine": m,
                    "Start": st,
                    "Processing Time": d,
                    "End": ed,
                    "Lateness": lateness_val,
                    "Tardiness": max(0, lateness_val),
                    "Earliness": max(0, -lateness_val)
                })

        df_schedule = pd.DataFrame.from_records(records).sort_values(["Start", "Job", "Operation"]).reset_index(drop=True)
    else:
        print(f"\nSolver-Status         : {solver.StatusName(status)}")
        print("No feasible solution found!")
        df_schedule = pd.DataFrame()

    # === Logging ===
    print(f"\nSolver-Status         : {solver.StatusName(status)}")
    print(f"Objective Value       : {solver.ObjectiveValue():.2f}")
    print(f"Best Objective Bound  : {solver.BestObjectiveBound():.2f}")
    print(f"Laufzeit              : {solver.WallTime():.2f} Sekunden")

    return df_schedule

# %%
starting_time = time.time()
df_reschedule = solve_cp_jssp_lateness_by_tardiness_and_earliness_with_fixed_ops(df_rest, df_time_rest, df_execution_important,
                                                                                 w_t = 5,
                                                                                 reschedule_start = 1440, msg=False, timeLimit=max_time, gapRel= 0)
# Informationen
ending_time = time.time()
solver_duration = ending_time - starting_time
print(f"\nScheduling-Dauer: {int(solver_duration // 60)} Minuten und {(solver_duration % 60):.2f} Sekunden.")
df_reschedule
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 281.00
# Best Objective Bound  : 281.00
# Laufzeit              : 9.28 Sekunden
#
# Scheduling-Dauer: 0 Minuten und 9.57 Sekunden.
#          Job  Operation  Arrival  Deadline Machine  Start  Processing Time  \
# 0    Job_011          5      894      2635      M9   1443               11
# 1    Job_014          1     1128      3037      M2   1443               95
# 2    Job_008          7      708      2449      M7   1446               89
# 3    Job_011          6      894      2635      M6   1454               40
# 4    Job_009          7      740      2315      M3   1460               52
# ..       ...        ...      ...       ...     ...    ...              ...
# 442  Job_051          9     4003      5449      M7   5424               25
# 443  Job_049          9     3774      5515      M8   5441               74
# 444  Job_054          9     4015      5671      M4   5638               33
# 445  Job_056          9     4234      5808      M7   5763               45
# 446  Job_052          9     4008      5917      M5   5874               43
#
#       End  Lateness  Tardiness  Earliness
# 0    1454     -1181          0       1181
# 1    1538     -1499          0       1499
# 2    1535      -914          0        914
# 3    1494     -1141          0       1141
# 4    1512      -803          0        803
# ..    ...       ...        ...        ...
# 442  5449         0          0          0
# 443  5515         0          0          0
# 444  5671         0          0          0
# 445  5808         0          0          0
# 446  5917         0          0          0
#
# [447 rows x 11 columns]

# %%
show.plot_gantt_machines(df_reschedule)
check.is_machine_conflict_free(df_reschedule)
check.is_operation_sequence_correct(df_reschedule)
check.is_job_timing_correct(df_reschedule)
check.is_start_correct(df_reschedule)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Für alle Jobs ist die Operationssequenz korrekt.
# + Zeitliche technologische Reihenfolge korrekt.
# + Alle Operation starten erst nach Arrival des Job
# True

# %%
last_ops = df_reschedule.sort_values(['Job', 'Operation']).drop_duplicates('Job', keep='last')
show.count_column_grouped(last_ops, "Lateness", max_val = 180, steps= 30)
# Out:
# label
# <-180           0
# -180 - -150     0
# -150 - -120     0
# -120 - -90      0
# -90 - -60       0
# -60 - -30       3
# -30 - 0         0
# 0              51
# 0 - 30          0
# 30 - 60         1
# 60 - 90         0
# 90 - 120        0
# 120 - 150       0
# 150 - 180       0
# >180            0
# Name: count, dtype: int32

# %%
last_ops.sort_values(by="Lateness", ascending= False)
# Out:
#          Job  Operation  Arrival  Deadline Machine  Start  Processing Time  \
# 9    Job_006          9      340      1553      M4   1529               55
# 12   Job_001          9       83      1570      M8   1540               30
# 411  Job_043          9     3182      4628      M7   4603               25
# 333  Job_032          9     2563      4009      M7   3984               25
# 393  Job_033          9     2568      4477      M5   4434               43
# ..       ...        ...      ...       ...     ...    ...              ...
# 264  Job_026          9     1928      3499      M3   3420               79
# 445  Job_056          9     4234      5808      M7   5763               45
# 438  Job_046          9     3588      5329      M8   5213               74
# 116  Job_008          9      708      2449      M8   2333               74
# 309  Job_027          9     2148      3889      M8   3773               74
#
#       End  Lateness  Tardiness  Earliness
# 9    1584        31         31          0
# 12   1570         0          0          0
# 411  4628         0          0          0
# 333  4009         0          0          0
# 393  4477         0          0          0
# ..    ...       ...        ...        ...
# 264  3499         0          0          0
# 445  5808         0          0          0
# 438  5287       -42          0         42
# 116  2407       -42          0         42
# 309  3847       -42          0         42
#
# [55 rows x 11 columns]

# %% [markdown]
# ### Combi aus Simulation und Neuplannung

# %%
# Relevante Spalten
columns_needed = ["Job", "Operation", "Arrival", "Machine", "Start", "Processing Time", "End"]

# Spalte in df_execution umbenennen
df_execution_important_renamed = df_execution.rename(columns={"Simulated Processing Time": "Processing Time"})

# Auf die gewünschten Spalten beschränken
df_exec_trimmed = df_execution_important_renamed[columns_needed]
df_resched_trimmed = df_reschedule[columns_needed]

# DataFrames zusammenführen
df_combined = pd.concat([df_exec_trimmed, df_resched_trimmed], ignore_index=True)
df_combined
# Out:
#          Job  Operation  Arrival Machine    Start  Processing Time      End
# 0    Job_000          0        0      M0     0.00            13.20    13.20
# 1    Job_000          1        0      M1    29.00           107.22   136.22
# 2    Job_000          2        0      M2   259.87             7.82   267.69
# 3    Job_000          3        0      M3   267.69            27.73   295.42
# 4    Job_000          4        0      M4   321.91            96.68   418.59
# ..       ...        ...      ...     ...      ...              ...      ...
# 565  Job_051          9     4003      M7  5424.00            25.00  5449.00
# 566  Job_049          9     3774      M8  5441.00            74.00  5515.00
# 567  Job_054          9     4015      M4  5638.00            33.00  5671.00
# 568  Job_056          9     4234      M7  5763.00            45.00  5808.00
# 569  Job_052          9     4008      M5  5874.00            43.00  5917.00
#
# [570 rows x 7 columns]

# %%
show.plot_gantt_machines(df_combined)
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
check.is_start_correct(df_combined)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Für alle Jobs ist die Operationssequenz korrekt.
# + Zeitliche technologische Reihenfolge korrekt.
# + Alle Operation starten erst nach Arrival des Job
# True
