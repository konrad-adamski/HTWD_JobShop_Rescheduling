# %% [markdown]
# # Rolling Planning mit Tardiness (Max)

# %%
import pandas as pd
import time
pd.set_option('display.max_rows', 20)

# %%
import utils.presenter as show
import utils.checker as check

import utils.rescheduling_solver_tardiness as rssv

from ProductionDaySimulation import ProductionDaySimulation

# %%
import utils.rolling_planning.init_jobs_times as rp_init
import utils.rolling_planning.procedure as rp_proced

# %% [markdown]
# ## Laden der Initialisierungsdaten

# %%
df_jssp = pd.read_csv("data/05_tardiness_all_jssp.csv")
df_times = pd.read_csv("data/05_tardiness_all_times.csv")

# %% [markdown]
# ### Tag 0

# %%
df_plan = pd.read_csv("data/05_tardiness_init_plan.csv")
df_execution = pd.read_csv("data/05_tardiness_init_execution.csv")
df_undone = pd.read_csv("data/05_tardiness_init_undone.csv")

# %% [markdown]
# ### Settings

# %%
max_time = 60*60*6 # 6h

# %%
def get_schedule_filename(prefix: str = "", day: int = 0, data_txt: str = "schedule", suffix: str = "") -> str:
    file_template = "data/{prefix}_{data}_{day:02d}{suffix}.csv"
    if suffix:
        suffix = f"_{suffix}"
    return file_template.format(prefix=prefix,data=data_txt,day=day, suffix=suffix)

# %% [markdown]
# ## Params

# %%
# fix
day_length = 1440
horizon_days = 3

notebook_prefix = "6b"

# %% [markdown]
# #### Rescheduling für Tage 1-5
# - Tag 1: Ankunfttermine in [1, 2, 3] + unabgeschlosse von Vortagen (evtl. Tag 0)
# - Tag 2: Ankunfttermine in [2, 3, 4] + unabgeschlosse von Vortagen (evtl. Tag 0 "oder" Tag 1)
# - ...
# - Tag 5: Ankunfttermine in [5, 6, 7] + unabgeschlosse von Vortagen

# %%
first_start = 1
last_planning_start = 5

# %%
for day_numb in range(first_start, last_planning_start + 1):
    day_start = day_length * day_numb
    day_end = day_start + day_length
    planning_end = day_start + horizon_days * day_length

    # ------------------- I. Ankunfts- und Operationsvorbereitung -------------------
    df_jssp_curr, df_times_curr = rp_proced.filter_jobs_by_arrival_window(df_times, df_jssp, day_start, planning_end)
    df_jssp_curr = rp_proced.extend_with_undone_operations(df_jssp_curr, df_undone)
    df_times_curr = rp_proced.update_times_after_operation_changes(df_times, df_jssp_curr)

    # ------------------- II. Relevante laufende Operationen -------------------------
    df_execution_important = rp_proced.get_operations_running_into_day(df_execution, day_start)

    # ------------------- III. Rescheduling durchführen -------------------------------

    starting_time = time.time()
    df_plan = rssv.solve_jssp_max_tardiness_with_devpen(df_jssp_curr, df_times_curr, df_execution_important, 
                                                        df_original_plan = df_plan, # prev. Plan
                                                        r = 0.45,                   # 45% Tardiness, 55% DevPen
                                                        reschedule_start = day_start,
                                                        solver= "HiGHS", msg=False, timeLimit=max_time, gapRel= 0.05, threads=7)
    solver_duration = time.time() - starting_time
    print(f"\n  Scheduling-Dauer: {int(solver_duration // 60)} Minuten und {(solver_duration % 60):.2f} Sekunden.")

    df_plan.to_csv(get_schedule_filename(notebook_prefix, day=day_numb, suffix="devpen"), index=False)

    show.plot_gantt_machines(df_plan, title=f"Gantt-Diagramm ab Tag {day_numb}")
    check.check_constraints(df_plan)
    print(show.count_column_grouped(df_plan, 'Tardiness'))

    # ------------------- IV. Einen Tag simulieren -------------------------------------

    simulation = ProductionDaySimulation(df_plan, vc=0.35)
    df_execution, df_undone = simulation.run(start_time=day_start, end_time=day_end)
    if not df_execution.empty:
        show.plot_gantt_machines(df_execution, title=f"Gantt-Diagramm für Simulationstag {day_numb}", duration_column="Simulated Processing Time")
    else:
        print(f"Nothing executed on day {day_numb}")
# Out:
# Solver-Informationen:
#   Zielfunktionswert       : 15160.756
#   Solver-Status           : Optimal
#   Anzahl Variablen        : 23217
#   Anzahl Constraints      : 45700
#
#   Scheduling-Dauer: 360 Minuten und 0.79 Sekunden.
# + Keine Maschinenkonflikte gefunden
# + Für alle Jobs ist die Operationssequenz korrekt.
# + Zeitliche technologische Reihenfolge korrekt.
# + Alle Operation starten erst nach Arrival des Job
#
# +++ Alle Constraints wurden erfüllt.
#
# <0             0
# 0            512
# 0-30          15
# 30-60          6
# 60-120        18
# 120-240       28
# 240-480       37
# 480-720       24
# 720-1440      21
# 1440-2880      0
# >2880          0
# dtype: int64
# [24:46:06] Job_009 started on M5
# [24:46:06] Job_012 started on M9
# [24:54:48] Job_012 finished on M9 (after 08 minutes 42 seconds)
# [25:05:01] Job_008 started on M1
# [25:05:01] Job_019 started on M0
# [25:12:41] Job_009 finished on M5 (after 26 minutes 35 seconds)
# [25:30:39] Job_019 finished on M0 (after 25 minutes 38 seconds)
# [25:33:06] Job_010 started on M5
# [25:34:01] Job_011 started on M0
# [25:34:13] Job_001 started on M8
# [25:34:13] Job_015 started on M7
# [25:45:25] Job_001 finished on M8 (after 11 minutes 12 seconds)
# [26:01:38] Job_003 started on M9
# [26:01:38] Job_017 started on M3
# [26:07:32] Job_008 finished on M1 (after 62 minutes 32 seconds)
# [26:14:01] Job_019 started on M1
# [26:20:49] Job_015 finished on M7 (after 46 minutes 36 seconds)
# [26:23:13] Job_007 started on M7
# [26:25:55] Job_017 finished on M3 (after 24 minutes 17 seconds)
# [26:28:04] Job_003 finished on M9 (after 26 minutes 26 seconds)
# [26:28:04] Job_015 started on M9
# [26:37:38] Job_012 started on M3
# [26:37:38] Job_017 started on M4
# [26:50:04] Job_007 finished on M7 (after 26 minutes 51 seconds)
# [26:51:02] Job_011 finished on M0 (after 77 minutes 01 second)
# [27:06:33] Job_010 finished on M5 (after 93 minutes 27 seconds)
# [27:06:33] Job_003 started on M5
# [27:22:04] Job_019 finished on M1 (after 68 minutes 03 seconds)
# [27:23:04] Job_017 finished on M4 (after 45 minutes 26 seconds)
# [27:32:01] Job_013 started on M1
# [27:32:01] Job_019 started on M2
# [27:33:11] Job_013 finished on M1 (after 01 minute 10 seconds)
# [27:39:02] Job_019 finished on M2 (after 07 minutes 01 second)
# [27:47:48] Job_010 started on M4
# [27:48:00] Job_012 finished on M3 (after 70 minutes 22 seconds)
# [27:48:00] Job_008 started on M3
# [27:48:00] Job_012 started on M1
# [27:51:43] Job_015 finished on M9 (after 83 minutes 38 seconds)
# [27:54:01] Job_003 finished on M5 (after 47 minutes 28 seconds)
# [27:54:01] Job_017 started on M5
# [28:01:52] Job_017 finished on M5 (after 07 minutes 50 seconds)
# [28:01:52] Job_013 started on M5
# [28:01:52] Job_017 started on M6
# [28:24:52] Job_012 finished on M1 (after 36 minutes 52 seconds)
# [28:24:52] Job_011 started on M1
# [28:40:42] Job_010 finished on M4 (after 52 minutes 53 seconds)
# [28:48:15] Job_017 finished on M6 (after 46 minutes 23 seconds)
# [28:48:15] Job_010 started on M6
# [28:48:15] Job_017 started on M7
# [29:06:13] Job_011 finished on M1 (after 41 minutes 21 seconds)
# [29:23:38] Job_016 started on M1
# [29:24:21] Job_013 finished on M5 (after 82 minutes 29 seconds)
# [29:39:38] Job_023 started on M2
# [29:54:08] Job_023 finished on M2 (after 14 minutes 30 seconds)
# [29:57:31] Job_017 finished on M7 (after 69 minutes 16 seconds)
# [30:29:48] Job_023 started on M0
# [30:30:06] Job_017 started on M8
# [30:32:20] Job_010 finished on M6 (after 104 minutes 06 seconds)
# [30:32:20] Job_015 started on M6
# [30:38:57] Job_023 finished on M0 (after 09 minutes 09 seconds)
# [31:06:47] Job_016 finished on M1 (after 103 minutes 09 seconds)
# [31:06:47] Job_016 started on M0
# [31:09:10] Job_015 finished on M6 (after 36 minutes 50 seconds)
# [31:09:10] Job_012 started on M6
# [31:15:02] Job_008 finished on M3 (after 207 minutes 02 seconds)
# [31:15:02] Job_009 started on M3
# [31:15:02] Job_008 started on M5
# [31:23:23] Job_017 finished on M8 (after 53 minutes 17 seconds)
# [31:23:23] Job_010 started on M8
# [31:29:38] Job_017 started on M9
# [31:33:54] Job_010 finished on M8 (after 10 minutes 31 seconds)
# [31:54:48] Job_023 started on M1
# [31:55:31] Job_017 finished on M9 (after 25 minutes 53 seconds)
# [31:55:31] Job_010 started on M9
# [32:00:29] Job_012 finished on M6 (after 51 minutes 19 seconds)
# [32:15:18] Job_008 finished on M5 (after 60 minutes 16 seconds)
# [32:15:18] Job_008 started on M2
# [32:18:17] Job_023 finished on M1 (after 23 minutes 29 seconds)
# [32:18:17] Job_025 started on M1
# [32:37:38] Job_012 started on M5
# [32:42:31] Job_009 finished on M3 (after 87 minutes 29 seconds)
# [32:42:31] Job_019 started on M3
# [32:42:31] Job_009 started on M4
# [32:56:32] Job_025 finished on M1 (after 38 minutes 15 seconds)
# [33:01:40] Job_010 finished on M9 (after 66 minutes 10 seconds)
# [33:01:40] Job_010 started on M7
# [33:02:48] Job_018 started on M1
# [33:13:57] Job_012 finished on M5 (after 36 minutes 19 seconds)
# [33:14:12] Job_016 finished on M0 (after 127 minutes 25 seconds)
# [33:14:55] Job_019 finished on M3 (after 32 minutes 24 seconds)
# [33:14:55] Job_011 started on M3
# [33:30:10] Job_010 finished on M7 (after 28 minutes 30 seconds)
# [33:34:38] Job_023 started on M5
# [33:50:48] Job_025 started on M0
# [33:54:55] Job_018 finished on M1 (after 52 minutes 07 seconds)
# [34:08:06] Job_012 started on M7
# [34:14:15] Job_008 finished on M2 (after 118 minutes 58 seconds)
# [34:14:15] Job_008 started on M9
# [34:17:49] Job_009 finished on M4 (after 95 minutes 19 seconds)
# [34:17:49] Job_019 started on M4
# [34:27:07] Job_025 finished on M0 (after 36 minutes 19 seconds)
# [34:27:48] Job_014 started on M1
# [34:27:48] Job_018 started on M0
# [34:30:12] Job_011 finished on M3 (after 75 minutes 17 seconds)
# [34:30:12] Job_013 started on M3
# [34:31:04] Job_008 finished on M9 (after 16 minutes 49 seconds)
# [34:31:04] Job_008 started on M6
# [34:38:30] Job_018 finished on M0 (after 10 minutes 42 seconds)
# [34:40:48] Job_020 started on M0
# [34:44:01] Job_023 finished on M5 (after 69 minutes 23 seconds)
# [34:44:01] Job_011 started on M5
# [35:14:26] Job_008 finished on M6 (after 43 minutes 22 seconds)
# [35:16:37] Job_011 finished on M5 (after 32 minutes 37 seconds)
# [35:16:37] Job_011 started on M2
# [35:17:53] Job_012 finished on M7 (after 69 minutes 47 seconds)
# [35:17:53] Job_009 started on M7
# [35:18:43] Job_020 finished on M0 (after 37 minutes 55 seconds)
# [35:20:06] Job_012 started on M8
# [35:23:40] Job_019 finished on M4 (after 65 minutes 50 seconds)
# [35:23:40] Job_019 started on M5
# [35:33:39] Job_019 finished on M5 (after 09 minutes 59 seconds)
# [35:33:39] Job_019 started on M6
# [35:33:52] Job_013 finished on M3 (after 63 minutes 41 seconds)
# [35:33:52] Job_016 started on M3
# [35:35:44] Job_014 finished on M1 (after 67 minutes 56 seconds)
# [35:49:07] Job_012 finished on M8 (after 29 minutes 01 second)
# [35:49:07] Job_013 started on M8
# [36:03:03] Job_009 finished on M7 (after 45 minutes 10 seconds)
# [36:03:03] Job_008 started on M7
# [36:06:43] Job_016 finished on M3 (after 32 minutes 50 seconds)
# [36:06:43] Job_007 started on M3
# [36:26:09] Job_019 finished on M6 (after 52 minutes 30 seconds)
# [36:28:42] Job_011 finished on M2 (after 72 minutes 04 seconds)
# [36:28:42] Job_016 started on M2
# [36:28:42] Job_011 started on M9
# [36:45:33] Job_011 finished on M9 (after 16 minutes 51 seconds)
# [36:45:33] Job_011 started on M6
# [36:46:21] Job_007 finished on M3 (after 39 minutes 38 seconds)
# [36:46:21] Job_025 started on M3
# [36:53:00] Job_013 finished on M8 (after 63 minutes 53 seconds)
# [36:53:00] Job_013 started on M9
# [37:11:09] Job_011 finished on M6 (after 25 minutes 36 seconds)
# [37:39:48] Job_025 finished on M3 (after 53 minutes 27 seconds)
# [37:39:48] Job_023 started on M3
# [37:42:42] Job_013 finished on M9 (after 49 minutes 41 seconds)
# [37:42:42] Job_013 started on M0
# [38:02:40] Job_023 finished on M3 (after 22 minutes 52 seconds)
# [38:02:40] Job_010 started on M3
# [38:02:40] Job_023 started on M4
# [38:07:28] Job_008 finished on M7 (after 124 minutes 25 seconds)
# [38:07:28] Job_019 started on M7
# [38:15:33] Job_016 finished on M2 (after 106 minutes 51 seconds)
# [38:15:33] Job_020 started on M2
# [38:16:38] Job_016 started on M8
# [38:40:58] Job_013 finished on M0 (after 58 minutes 17 seconds)
# [38:40:58] Job_013 started on M6
# [38:45:02] Job_019 finished on M7 (after 37 minutes 34 seconds)
# [38:45:02] Job_011 started on M7
# [38:47:05] Job_010 finished on M3 (after 44 minutes 26 seconds)
# [39:38:15] Job_016 finished on M8 (after 81 minutes 37 seconds)
# [39:38:15] Job_019 started on M8
# [39:46:38] Job_016 started on M5
# [40:01:13] Job_013 finished on M6 (after 80 minutes 14 seconds)
# [40:05:57] Job_016 finished on M5 (after 19 minutes 19 seconds)
# [40:09:02] Job_023 finished on M4 (after 126 minutes 22 seconds)
# [40:09:02] Job_008 started on M4
# [40:15:31] Job_019 finished on M8 (after 37 minutes 16 seconds)
# [40:15:31] Job_023 started on M8
# [40:15:31] Job_019 started on M9
# [40:17:11] Job_011 finished on M7 (after 92 minutes 09 seconds)
# [40:17:11] Job_016 started on M7
# [40:17:26] Job_020 finished on M2 (after 121 minutes 53 seconds)
# [40:17:26] Job_025 started on M2
# [40:24:02] Job_023 finished on M8 (after 08 minutes 31 seconds)
# [40:25:10] Job_025 finished on M2 (after 07 minutes 44 seconds)
# [40:25:10] Job_018 started on M2
# [40:41:24] Job_016 finished on M7 (after 24 minutes 13 seconds)
# [40:41:24] Job_023 started on M7
# [40:43:39] Job_019 finished on M9 (after 28 minutes 08 seconds)
# [40:52:46] Job_008 finished on M4 (after 43 minutes 44 seconds)
# [40:52:46] Job_013 started on M4
# [40:52:46] Job_008 started on M8
# [40:59:52] Job_013 finished on M4 (after 07 minutes 07 seconds)
# [40:59:52] Job_011 started on M4
# [41:20:38] Job_025 started on M6
# [41:22:37] Job_023 finished on M7 (after 41 minutes 14 seconds)
# [41:22:37] Job_013 started on M7
# [41:22:37] Job_023 started on M9
# [41:24:52] Job_018 finished on M2 (after 59 minutes 42 seconds)
# [41:24:52] Job_014 started on M2
# [41:25:23] Job_011 finished on M4 (after 25 minutes 31 seconds)
# [41:25:23] Job_020 started on M4
# [41:33:36] Job_013 finished on M7 (after 10 minutes 59 seconds)
# [41:55:27] Job_023 finished on M9 (after 32 minutes 49 seconds)
# [42:01:12] Job_008 finished on M8 (after 68 minutes 26 seconds)
# [42:01:12] Job_011 started on M8
# [42:03:27] Job_025 finished on M6 (after 42 minutes 49 seconds)
# [42:03:27] Job_018 started on M6
# [42:03:27] Job_025 started on M5
# [42:09:26] Job_018 finished on M6 (after 05 minutes 59 seconds)
# [42:09:26] Job_016 started on M6
# [42:14:03] Job_020 finished on M4 (after 48 minutes 40 seconds)
# [42:14:03] Job_020 started on M9
# [42:20:43] Job_020 finished on M9 (after 06 minutes 40 seconds)
# [42:20:43] Job_020 started on M3
# [42:30:49] Job_025 finished on M5 (after 27 minutes 22 seconds)
# [42:33:38] Job_021 started on M1
# [42:44:02] Job_014 finished on M2 (after 79 minutes 11 seconds)
# [42:44:02] Job_024 started on M2
# [42:44:02] Job_014 started on M0
# [42:47:52] Job_011 finished on M8 (after 46 minutes 40 seconds)
# [42:47:52] Job_018 started on M8
# [43:28:12] Job_018 finished on M8 (after 40 minutes 20 seconds)
# [43:28:12] Job_018 started on M9
# [43:50:34] Job_021 finished on M1 (after 76 minutes 56 seconds)
# [43:58:10] Job_020 finished on M3 (after 97 minutes 27 seconds)
# [43:58:10] Job_020 started on M1
# [44:03:47] Job_014 finished on M0 (after 79 minutes 45 seconds)
# [44:03:47] Job_014 started on M4
# [44:04:38] Job_021 started on M0
# [44:19:56] Job_024 finished on M2 (after 95 minutes 53 seconds)
# [44:19:56] Job_026 started on M2
# [44:20:02] Job_016 finished on M6 (after 130 minutes 35 seconds)
# [44:20:02] Job_023 started on M6
# [44:20:33] Job_020 finished on M1 (after 22 minutes 23 seconds)
# [44:20:33] Job_024 started on M1
# [44:21:52] Job_024 finished on M1 (after 01 minute 19 seconds)
# [44:21:52] Job_024 started on M5
# [44:30:22] Job_018 finished on M9 (after 62 minutes 10 seconds)
# [44:30:22] Job_025 started on M9
# [44:50:38] Job_022 started on M1
# [44:58:40] Job_026 finished on M2 (after 38 minutes 44 seconds)
# [44:59:36] Job_025 finished on M9 (after 29 minutes 14 seconds)
# [44:59:36] Job_016 started on M9
# [44:59:36] Job_025 started on M8
# [45:00:01] Job_021 finished on M0 (after 55 minutes 23 seconds)
# [45:00:01] Job_026 started on M0
# [45:17:39] Job_014 finished on M4 (after 73 minutes 52 seconds)
# [45:21:28] Job_024 finished on M5 (after 59 minutes 35 seconds)
# [45:21:28] Job_018 started on M5
# [45:21:28] Job_024 started on M3
# [45:23:54] Job_023 finished on M6 (after 63 minutes 52 seconds)
# [45:23:54] Job_020 started on M6
# [45:37:26] Job_022 finished on M1 (after 46 minutes 48 seconds)
# [45:55:26] Job_020 finished on M6 (after 31 minutes 32 seconds)
# [45:55:26] Job_014 started on M6
# [46:01:35] Job_014 finished on M6 (after 06 minutes 10 seconds)
# [46:11:38] Job_028 started on M1
# [46:11:38] Job_022 started on M2
# [46:12:41] Job_018 finished on M5 (after 51 minutes 13 seconds)
# [46:12:41] Job_020 started on M5
# [46:20:53] Job_024 finished on M3 (after 59 minutes 25 seconds)
# [46:20:53] Job_018 started on M3
# [46:23:31] Job_026 finished on M0 (after 83 minutes 30 seconds)
# [46:28:52] Job_025 finished on M8 (after 89 minutes 16 seconds)
# [46:28:52] Job_014 started on M8
# [46:28:52] Job_025 started on M7
# [46:59:47] Job_020 finished on M5 (after 47 minutes 06 seconds)
# [47:01:20] Job_016 finished on M9 (after 121 minutes 44 seconds)
# [47:01:20] Job_016 started on M4
# [47:09:27] Job_014 finished on M8 (after 40 minutes 34 seconds)
# [47:09:27] Job_024 started on M8
# [47:27:35] Job_025 finished on M7 (after 58 minutes 43 seconds)
# [47:27:35] Job_020 started on M7
# [47:27:43] Job_028 finished on M1 (after 76 minutes 05 seconds)
# [47:27:43] Job_026 started on M1
# [47:28:31] Job_018 finished on M3 (after 67 minutes 38 seconds)
# [47:28:31] Job_021 started on M3
# [47:38:25] Job_024 finished on M8 (after 28 minutes 58 seconds)
# [47:47:38] Job_024 started on M9
# [47:48:19] Job_016 finished on M4 (after 46 minutes 58 seconds)
# [47:48:19] Job_025 started on M4
# [48:15:34] Job_021 finished on M3 (after 47 minutes 02 seconds)
# [48:18:01] Job_026 finished on M1 (after 50 minutes 18 seconds)
# [48:18:01] Job_026 interrupted before machine M5 — would start too late (after 48:00:00)
# [48:20:55] Job_025 finished on M4 (after 32 minutes 37 seconds)
# [48:20:55] Job_018 interrupted before machine M4 — would start too late (after 48:00:00)
# [48:37:03] Job_020 finished on M7 (after 69 minutes 28 seconds)
# [48:37:03] Job_014 interrupted before machine M7 — would start too late (after 48:00:00)
# [48:37:03] Job_020 interrupted before machine M8 — would start too late (after 48:00:00)
# [48:39:02] Job_022 finished on M2 (after 147 minutes 25 seconds)
# [48:39:02] Job_021 interrupted before machine M2 — would start too late (after 48:00:00)
# [48:39:02] Job_022 interrupted before machine M0 — would start too late (after 48:00:00)
# [49:38:25] Job_024 finished on M9 (after 110 minutes 47 seconds)
#
# [49:38:25] Simulation ended! There are no more active Operations
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 36
#      34 df_execution, df_undone = simulation.run(start_time=day_start, end_time=day_end)
#      35 if not df_execution.empty:
# ---> 36     if plot_results:
#      37         show.plot_gantt_machines(df_execution, title=f"Gantt-Diagramm für Simulationstag {day_numb}", duration_column="Simulated Processing Time")
#      38 else:
#
# NameError: name 'plot_results' is not defined
